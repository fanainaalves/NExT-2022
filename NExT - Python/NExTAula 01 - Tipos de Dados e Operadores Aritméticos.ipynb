# %% [markdown]
# <img src="https://www.cesar.school/wp-content/uploads/2019/09/marca_cesar_school.png" alt="drawing" width="200"/>
#
# # 🐍 Python - **Aula 01**
#
# ---
#
# - Variáveis;
# - Tipos de Dados;
# - Entrada e saída de dados;
# - Operadores aritméticos;

# %% [markdown]
# # 📦 Variáveis
#
# Em termos técnicos, uma variável atribui um local de armazenamento a um valor que está vinculado a um nome ou identificador simbólico. O nome da variável é usado para fazer referência a esse valor armazenado em um programa de computador.
#
# Python é uma linguagem de tipagem **dinâmica** e **forte**:
# *   **Tipagem Dinâmica**: o interpretador Python infere qual o tipo do dado que a variável está recebendo (não é necessário inserir explicitamente);
# *   **Tipagem Forte**: o interpretador Python **não** faz coerções automáticas (conversões de valores) entre tipos não compatíveis.
#
# Desta forma, para criar uma variável em Python, basta declarar seu nome e atribuir um valor.

# %%
idade = 29
altura = 1.86

# %% [markdown]
# * o nome da variável: `idade`
# * o operador de atribuição, também conhecido como 'recebe': `=`
# * o valor que está sendo vinculado ao nome da variável `29`
#
# ⚠️ Em Python, não é possível declarar uma variável sem atribuir um valor a ela

# %% [markdown]
# ## Regras para criação de nomes de variáveis:
#
# - Não pode começar com número;
# - Não pode haver espaço (use `_`);
# - Não pode haver caracteres especiais: `" ' , < > | / \ ( ) @ ! # $ % ^ & * ~ - +`

# %% [markdown]
# ## Reatribuindo Variáveis
#
# Depois que uma variável é criada, ela pode receber qualquer outro valor, de qualquer outro tipo

# %%
idade = 29
idade = "Oxe"
idade = 10

# %% [markdown]
# # 📤Exibindo Valores - `print`

# %% [markdown]
# Para exibir um valor no console, use o comando `print()`.
#
# > 💡 *É possível exibir vários valores em um único `print()`*

# %%
idade = 29
print(idade)
# Out:
# 29

# %%
idade = 29
altura = 1.86

print(idade, altura, 12, 'eita', True)
print('exemplo')
# Out:
# 29 1.86 12 eita True
# exemplo

# %% [markdown]
# > 👍 A função `print()` já adiciona, automaticamente uma quebra de linha no final

# %% [markdown]
# # Atribuição Múltipla
#
# Com Python, você pode atribuir um único valor a várias variáveis ​​ao mesmo tempo. Isso permite inicializar várias variáveis ​​de uma vez, que você mesmo pode reatribuir posteriormente no programa ou por meio da entrada do usuário.

# %%
x = y = z = 0

print(x, y, z)
# Out:
# 0 0 0

# %% [markdown]
# Outra possibilidade é atribuir vários valores diferentes para variáveis específicas

# %%
x, y, z = 10, 'Pedro', 20

print(x, y, z)
# Out:
# 10 Pedro 20

# %% [markdown]
# # ✍️ Strings - `str`
#
# As strings (*cadeia*) são tipos de dados que representam textos. Em Python, podem ser definidas usando aspas simples `'` ou duplas `"`.
#
# ```python
# texto1 = 'Esta é uma string entre aspas simples.'
#
# texto2 = "Esta é uma string entre aspas duplas."
# ```
#
# 💡 Existe ainda a possibiidade de usar as aspas triplas (3 aspas simples ou 3 aspas duplas)
# ```python
# texto3 = '''Esta é uma string
# pode ter
# várias linhas'''
# ```

# %%
nome = 'Luiz'
sobrenome = "Eduardo"

musica = '''Olha que coisa mais linda
  mais cheia de graça
    é ela que vem e que passa
'''

print(nome, sobrenome)
print(musica)
# Out:
# Luiz Eduardo
# Olha que coisa mais linda
#   mais cheia de graça
#     é ela que vem e que passa

# %% [markdown]
# # `#` Comentário
#
# Os comentários são trechos de código que são ignorados pelo interpretador. Podem ser usados para documentar ou suprimir pedaços do código para testes.
#
# Existem 3 tipos de comentários em Python:
# ```python
# # comentário de linha
#
# '''
# Comentário de bloco
# que pode ter várias linhas
# '''
#
# num = 10 # comentário inline
# ```

# %%
num = 10 + 5 # uma soma

print(num)
# Out:
# 15

# %% [markdown]
# # 🔢 Tipos de dados
#
# ## Numéricos
# - `int` - Inteiros
# - `float` - Pontos flutuantes
#
# ## Texto
# - `str` - String
#
# ## Booleano
# - `bool` - Lógico. Pode ser `True` ou `False`
#
# ##Listas
# - `list` - [ ]
#
# ## Sets
# - `set` - { }
#
# ##Tuplas
# - `tuples` - ( )
#
# ##Dicionários
# - `dictionary` - { }

# %% [markdown]
# 💡Para verificar o tipo de uma variável, é possível usar a função `type()`

# %%
# Exibir os tipos dos dados usando a função type()
idade = 29

print(type(idade))
print(type('Limongi'))

altura = 1.75
print(type(altura))

print(type(1.0))

print(type(True))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # 📥 Entrada de Dados - `input()`
#
# É possível receber dados lidos do console através do método `input()`
#
# Ele retorna o valor lido, que pode ser atribuído a uma variável.
#
# ```python
# entrada = input()
# ```
#
# 💡 É possível adicionar uma mensagem ao `input()`
#
# ```python
# entrada = input('Insira um valor')
# ```

# %%
altura = float(input())

print('A pessoa tem uma altura de', altura + 0.75)
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-d463a07d4199> in <module>
#       1 altura = input()
#       2
# ----> 3 print('A pessoa tem uma altura de', altura + 0.75)
#
# TypeError: can only concatenate str (not "float") to str

# %% [markdown]
# # 🔃 Funções para conversão de tipo
#
# Algumas vezes é necessário converter valores de um tipo para outro. As funções `int()`, `float()` e `str()` tentarão converter seus argumentos para os tipos `int`, `float` e `str`, respectivamente.
#
# ```python
# int()
# float()
# bool()
# str()
# ```

# %% [markdown]
# ## Convertendo os valores

# %%
# int → float
num = 10
#num = float(num)
print(float(num))

# float → int


# bool → int


# str → int
num = '30'
num = int(num)
print(num + 1)

valor = '12'
valor = int(valor)
print(valor)

# str → float
numero = '12.3'
print(float(numero))

outro_numero = 'oxe'
#print(float(outro_numero))

# str → bool


# int → str


# float → str


# bool → str
# Out:
# 10.0
# 31
# 12
# 12.3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-caf3a81b46ca> in <module>
#      24
#      25 outro_numero = 'oxe'
# ---> 26 print(float(outro_numero))
#      27
#      28 # str → bool
#
# ValueError: could not convert string to float: 'oxe'

# %% [markdown]
# ## Convertendo com `input()`

# %%
# Transformando um input em número
altura = float(input())

print('A pessoa tem uma altura de', altura + 0.75)
# Out:
# 1.45
# A pessoa tem uma altura de 2.2

# %% [markdown]
# # 🧮 Operações Aritméticas
#
# Em Python as 4 operações aritméticas básicas são feitas usando os operadores tradicionais `+`, `-`, `*` e `/`.
#
# - `x + y`:	soma de x e y
# - `x - y`:	subtração de x e y
# - `x * y`:	multiplicação de x e y
# - `x / y`:	divisão de x e y
#
# 💡 Qualquer divisão usando o operador `/`, mesmo que usando números `int`, gera um resultado em `float`
#
# Os operadores de `+`  e `-` também podem ser usados para manipular o sinal do número:
#
# - `+x`:	identidade de x
# - `-x`:	sinal alterado de x
#
# Python também dispõe de outros operadores :
#
# - `x % y`:	resto da divisão de x por y
# - `x // y`:	divisão **inteira** de x e y
# - `x ** y`:	x elevado a potência de y (`xʸ`)

# %%
print(10/2)
print(10//2)
print(3**.5)
# Out:
# 5.0
# 5
# 1.7320508075688772

# %% [markdown]
# ## Precedência Aritmética
#
# A ordem das operações aritméticas em Python é semelhante a matemática e pode ser modificada com o uso de parênteses `()`
#
# A precedência aritmética em Python segue a ordem:
# 1. `()`
# 2. `**`
# 3. `*`, `/` (*left-associative*)
# 4. `+`, `-` (*left-associative*)
#
# ```python
# 2 + 10 * 10 - 5 # 97
# (2 + 10) * (10 - 5) # 60
# ```

# %%
print(2 + 10 * 10 - 5)
print((2 + 10) * (10 - 5))
# Out:
# 97
# 60

# %% [markdown]
# ## Operadores de atribuição
#
#
# * `+=` - - adiciona e atribui o valor
# * `-=` - - subtrai e atribui o valor
# * `*=` - - multiplica e atribui o valor
# * `/=` - - divide e atribui o valor
# * `//=` - - divide e depois atribuir o valor em inteiro
# * `**=` - - aumentar a potência e então atribuir o valor
# * `%=` - - retorna o resto da divisão e depois atribui o valor
#
# 💡 Não existe `++` ou `--` em Python ㄟ( ▔, ▔ )ㄏ

# %%
num = 10

#num = num + 2
num += 2

#num = num // 2
num //= 2

print(num)
# Out:
# 6

# %% [markdown]
# # 🐝 Exercícios Beecrowd
#
# O Beecrowd é uma ferramenta que fornece questões de programação que podem ser resolvidas em várias linguagens. Seu código é corrigido de forma automática. Cadastre-se de forma gratuita [aqui](https://www.beecrowd.com.br/judge/en/login).
#
# 💡 *Todas as questões estão disponíveis em português* 👍

# %% [markdown]
# [1000 - Hello World](https://www.beecrowd.com.br/judge/pt/problems/view/1000)

# %%
# -*- coding: utf-8 -*-
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# [1001 - Extremamente Básico](https://www.beecrowd.com.br/judge/pt/problems/view/1001)

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# [1004 - Produto Simples](https://www.beecrowd.com.br/judge/pt/problems/view/1004)

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# # 🧱 Exercícios Fundamentais

# %% [markdown]
# 1. Faça um programa que mostre a mensagem "Alô mundo!" na tela

# %%
print("Alô mundo!")
# Out:
# Alô mundo!

# %% [markdown]
# 2. Faça um programa que peça um número e então mostre a mensagem `O número informado foi [número]`.

# %%
numero = int(input("Digite um número: "))
print("o número informado foi [{}]" .format(numero))
# Out:
# Digite um número: 20
# o número informado foi [20]

# %% [markdown]
# 3. Faça um Programa que peça dois números e imprima a soma deles.

# %%
num1 = int(input("Digite um número: "))
num2 = int(input("Digite outro número: "))
soma = num1 + num2
print("-> {} + {} = {} ".format(num1, num2, soma))
# Out:
# Digite um número: 2
# Digite outro número: 5
# -> 2 + 5 = 7

# %% [markdown]
# 4. Faça um programa que peça as 4 notas bimestrais e mostre a média.

# %%
nota1 = float(input("Digite a 1ª nota: "))
nota2 = float(input("Digite a 2ª nota: "))
nota3 = float(input("Digite a 3ª nota: "))
nota4 = float(input("Digite a 4ª nota: "))
media = (nota1 + nota2 + nota3 + nota4) / 4
print("A média é igual à: {}" .format(media))
# Out:
# Digite a 1ª nota: 10
# Digite a 2ª nota: 10
# Digite a 3ª nota: 10.0
# Digite a 4ª nota: 10.0
# A média é igual à: 10.0

# %% [markdown]
# 5. Faça um programa que converta metros para centímetros.

# %%
metros = float(input("Digite o valor em m para conversão em cm: "))
centimetros = metros * 100
print("{}m equivale à {}cm." .format(metros, centimetros))
# Out:
# Digite o valor em m para conversão em cm: 1.58
# 1.58m equivale à 158.0cm.

# %% [markdown]
# 6. Faça um programa que peça o raio de um círculo, calcule e mostre sua área.

# %%
raio = float(input("Digite o raio do circulo: "))
area = (3.14 * (raio ** 2))
print("A area do circulo é: {}" .format(area))
# Out:
# Digite o raio do circulo: 5
# A area do circulo é: 78.525

# %% [markdown]
# 7. Faça um programa que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

# %%
area = float(input("Digite o numero para calcular a area do quadrado: "))
calcArea = (area * area) 
dobro = (area * area) * 2
print("A àrea é igual à: {} \nO dobro da àrea é igual à: {}" .format(calcArea, dobro))
# Out:
# Digite o numero para calcular a area do quadrado: 5
# A àrea é igual à: 25.0
# O dobro da àrea é igual à: 50.0

# %% [markdown]
# 8. Faça um programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
valorHora = float(input('Quanto voce ganha por hora? R$ '))
numHoras = float(input('Quantas horas voce trabalha por mês? '))
salario = valorHora * numHoras
print('O seu salário é igual à: R$ ', salario)
# Out:
# Quanto voce ganha por hora? R$ 1.50
# Quantas horas voce trabalha por mês? 40.3
# O seu salário é igual à: R$  60.449999999999996

# %% [markdown]
# 9. Faça um programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
#   $ °C = 5 \times ((°F-32) / 9) $

# %%
faren = float(input('Digite a temperatura em Fahrenheit: '))
celsius = 5 * ((faren - 32) /9)
print('{}°F -> {} °C.' .format(faren, celsius))
# Out:
# Digite a temperatura em Fahrenheit: 25
# 25.0°F -> -3.888888888888889 °C.

# %% [markdown]
# 10. Faça um programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
#
#   $ °F = (°C \times 9 / 5) + 32 $

# %%
celsius = float(input('Digite a temperatura em Celsius: '))
faren = (celsius * 9/5) + 32
print('{} °C -> {}°F.' .format(celsius, faren))
# Out:
# Digite a temperatura em Celsius: 25
# 25.0 °C -> 77.0°F.

# %% [markdown]
# 11. Faça um programa que peça 2 números inteiros e um número real. Calcule e mostre:
# - O produto do dobro do primeiro com metade do segundo.
# - Soma do triplo do primeiro com o terceiro.
# - Terceiro elevado ao cubo.

# %%
num1 = int(input('Digite um numero inteiro: '))
num2 = int(input('Digite um numero inteiro: '))
num3 = float(input('Digite um numero real: '))
produto = (num1*2) + num2/2
soma = (num1 * 3) + num3
cubo = num3**3
print('produto ', produto)
print('produto ', soma)
print('produto ', cubo)
# Out:
# Digite um numero inteiro: 5
# Digite um numero inteiro: 4
# Digite um numero real: 2.0
# produto  12.0
# produto  17.0
# produto  8.0

# %% [markdown]
# 12. Tendo como dados de entrada a altura de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
#
#   $ peso\_ideal = (72.7 \times altura) - 58 $

# %%
altura = float(input('Digite a altura: '))
pesoIdeal = (72.7 * altura) - 58
print('O seu peso ideal é: ', pesoIdeal)

# %% [markdown]
# 13. Tendo como dado de entrada a altura ($h$) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# - Para homens: $ (72.7 \times h) - 58 $
# - Para mulheres: $ (62.1 \times h) - 44.7 $

# %%
alturaHomem = float(input('Digite a altura (Homem): '))
alturaMulher = float(input('Digite a altura (Mulher): '))
pesoIdealHomem = (72.7 * alturaHomem) - 58
pesoIdealMulher = (62.1 * alturaMulher) - 44.7
print('O peso ideal (Homem) é: ', pesoIdealHomem)
print('O peso ideal (Mulher) é: ', pesoIdealMulher)
# Out:
# Digite a altura (Homem): 1.58
# Digite a altura (Mulher): 1.58
# O peso ideal (Homem) é:  56.866000000000014
# O peso ideal (Mulher) é:  53.418000000000006

# %% [markdown]
# # 🤿 Exercícios de Aprofundamento
#
# ⚠️ Alguns desses exercícios exigem conhecimentos ainda não apresentados no curso!

# %% [markdown]
# 14. João Papo-de-Pescador, homem de bem, comprou um microcomputador para controlar o rendimento diário de seu trabalho. Toda vez que ele traz um peso de peixes maior que o estabelecido pelo regulamento de pesca do estado de São Paulo (50 quilos) deve pagar uma multa de R\$ 4,00 por quilo excedente. João precisa que você faça um programa que leia a variável peso (peso de peixes) e calcule o excesso. Gravar na variável excesso a quantidade de quilos além do limite e na variável multa o valor da multa que João deverá pagar. Imprima os dados do programa com as mensagens adequadas.

# %%
pesoPeixeAtual = float(input('Digite o peso do peixe: '))
if pesoPeixeAtual > 50:
  excesso = pesoPeixeAtual - 50
  multa = excesso * 4.0

else:
  excesso = 'ZERO'
  multa = 'ZERO'

print("O excesso de peso foi de: kl {}\nA multa foi de R$ {}" .format(excesso, multa))
# Out:
# Digite o peso do peixe: 52
# O excesso de peso foi de: kl 2.0
# A multa foi de R$ 8.0.

# %% [markdown]
# 15. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês, sabendo-se que são descontados 11% para o Imposto de Renda, 8% para o INSS e 5% para o sindicato, faça um programa que nos dê:
#     - salário bruto.
#     - quanto pagou ao INSS.
#     - quanto pagou ao sindicato.
#     - o salário líquido.
#     - calcule os descontos e o salário líquido, conforme a tabela abaixo:
#
# ```
#             + Salário Bruto : R$
#             - IR (11%) : R$
#             - INSS (8%) : R$
#             - Sindicato ( 5%) : R$
#             = Salário Liquido : R$
# ```
# > Obs.: Salário Bruto - Descontos = Salário Líquido.

# %%
valorHora = float(input('Quanto voce ganha por hora? R$ '))
numHoras = float(input('Quantas horas voce trabalha por mês? '))

salarioBruto = valorHora * numHoras
IR = salarioBruto * 0.11 
Inss = salarioBruto * 0.08
Sindicato = salarioBruto * 0.05
descontos = IR + Inss + Sindicato
salarioLiquido = salarioBruto - descontos

print('Salário bruto => R$ ', salarioBruto)
print('IR => R$ ', IR )
print('INSS => R$ ', Inss)
print('Sindicato => R$ ', Sindicato)
print('Salario Liquido => R$ ', salarioLiquido)
# Out:
# Quanto voce ganha por hora? R$ 50
# Quantas horas voce trabalha por mês? 200
# Salário bruto => R$  10000.0
# IR => R$  1100.0
# INSS => R$  800.0
# Sindicato => R$  500.0
# Salario Liquido => R$  7600.0

# %% [markdown]
# 16. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. Obs.: somente são vendidos um número inteiro de latas.

# %%
areaPintar = float(input('Qual o tamanho em m2 da area a ser pintada? '))
litrosTinta =  areaPintar / 3
if areaPintar % 54 == 0:
	latas = areaPintar / 54
else: 
	latas = int(areaPintar / 54) + 1
preco = latas * 80
print ('Latas de Tinta', latas)
print ('R$ ', preco)
# Out:
# Qual o tamanho em m2 da area a ser pintada? 40
# Latas de Tinta 1
# R$  80

# %% [markdown]
# 17. Faça um Programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 6 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00 ou em galões de 3,6 litros, que custam R\$ 25,00.
#   - Informe ao usuário as quantidades de tinta a serem compradas e os respectivos preços em 3 situações:
#   - comprar apenas latas de 18 litros;
#   - comprar apenas galões de 3,6 litros;
#   - misturar latas e galões, de forma que o desperdício de tinta seja menor. Acrescente 10% de folga e sempre arredonde os valores para cima, isto é, considere latas cheias.

# %%
tamanho = float(input('Entre com o tamanho da área: '))

litros = tamanho / 6
latas = litros / 18
if latas % 18 != 0:
    latas += 1
preco = latas * 80
galoes = litros / 3.6
if galoes % 3.6 != 0:
    galoes += 1
preco2 = galoes * 25

mistura_lata = int(litros / 18.0)
mistura_galao = int((litros - (mistura_lata * 18)) / 3.6)

if litros - (mistura_lata * 18) % 3.6 != 0:
    mistura_galao += 1

print('Apenas latas de 18 litros: %d' % latas, 'preço: %d' % preco)
print('Apenas galões de 3.6 litros: %d' % galoes, 'preço: %d' % preco2)
print('Mistura: %d latas e %d galoes = %.2f' % (
    mistura_lata, mistura_galao, ((mistura_lata * 80) + (mistura_galao * 25))))

# %% [markdown]
# 18. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).

# %%
tamanho = float(input('Tamanho do arquivo (MB): '))
velocidade = float(input('Velocidade de Internet (MBps): '))
print('Tempo aproximado de download: %.0f Minutos ' %((tamanho / velocidade) * 60))
