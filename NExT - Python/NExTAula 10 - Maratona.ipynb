# %% [markdown]
# <img src="https://www.cesar.school/wp-content/uploads/2019/09/marca_cesar_school.png" alt="drawing" width="200"/>
#
# # 🐍 Python - **Aula 10**
# ---
#
# - Maratona de Programação

# %% [markdown]
# # 🐝 Beecrowd
#
# ![Beecrowd](https://www.beecrowd.com.br/judge/img/5.0/logo-beecrowd.png?1635097036)
#
# O Beecrowd é um projeto brasileiro que promove a prática de programação atavés de um sistema que avalia de forma automática a execução de códigos através de uma ferramenta on-line.
#
# Ele possui mais de 1000 questões, dividios em 8 grandes categorias. Disponíveis em Portugês e Inglês.
#
# ## Como participar do nosso torneio:
#
# Para participar do torneio de hoje, siga os seguintes passos:
#
# 1. Crie um time.
#
#   Para criar um time, acesse esse [link](https://www.beecrowd.com.br/judge/pt/teams) > clique em `CRIAR TIME`:
#     - defina um nome criativo (e não ofensivo);
#     - o capitção é a pessoa que está criando;
#     - coloque os emails dos outros membros do time (o mesmo email que eles usaram parar se inscrever no Beecrowd).
#
# 2. Increva-se no torneio
#
#   O torneio está disponível nesse [link](https://www.beecrowd.com.br/judge/pt/tournaments/rank/6178).
#
#   Para se registrar, clique em "Registrar".
#   - Selecione o time que você criou
#   - Insira a senha: `next`
#
# 3. Enviando as questões
#
#   As questões são as **letras** na barra de cima. Ao clicar na letra, você terá acesso a questão.
#
# ![image.png](data:image/png;base64,...)
#
#   > 💡 Tente responder as questões primeiro aqui no colab, para testar e quando estiver pronto, cole o código no Beecrowd.
#
# ### Sobre as submissões:
#   - Se seu time ainda não tentou a questão, aparecerá um ponto image.png
#   - Para cada tentativa, o número de tentativas aparecerá em um círculo branco: ![image.png](data:image/png;base64,...)
#   - Quando você ou alguém do seu time acertar a questão, o círculo fica colorido ![image.png](data:image/png;base64,...)
#
# > ❓ FAQ: [Status das questões](https://www.urionlinejudge.com.br/judge/pt/answers)

# %% [markdown]
# # Questões

# %% [markdown]
# [1003 - Soma Simples](https://www.beecrowd.com.br/judge/pt/problems/view/1003)

# %%
# -*- coding: utf-8 -*-
'''Leia dois valores inteiros, no caso para variáveis A e B. A seguir, calcule a soma entre elas e atribua à variável SOMA. 
A seguir escrever o valor desta variável.

Entrada
O arquivo de entrada contém 2 valores inteiros.

Saída
Imprima a mensagem "SOMA" com todas as letras maiúsculas, com um espaço em branco antes 
e depois da igualdade seguido pelo valor correspondente à soma de A e B. Como todos os problemas, 
não esqueça de imprimir o fim de linha após o resultado, caso contrário, você receberá "Presentation Error".'''

A = int(input('Digite um numero: '))
B = int(input('Digite outro numero: '))
soma = A + B
print("SOMA = ", soma ," ")
# Out:
# Digite um numero: 5
# Digite outro numero: 4
# SOMA =  9

# %% [markdown]
# [1008 - Salário](https://www.beecrowd.com.br/judge/pt/problems/view/1008)

# %%
# -*- coding: utf-8 -*-

''' Escreva um programa que leia o número de um funcionário, seu número de horas trabalhadas, 
o valor que recebe por hora e calcula o salário desse funcionário. A seguir, mostre o número e o salário do funcionário, com duas casas decimais.

Entrada
O arquivo de entrada contém 2 números inteiros e 1 número com duas casas decimais, representando o número, quantidade de horas trabalhadas e
 o valor que o funcionário recebe por hora trabalhada, respectivamente.

Saída
Imprima o número e o salário do funcionário, conforme exemplo fornecido, com um espaço em branco antes e depois da igualdade.
 No caso do salário, também deve haver um espaço em branco após o $.'''

numeroFuncionario = int(input())
horasTrab = float(input())
valorHoras= float(input())

salario = horasTrab * valorHoras

print(f'NUMERO = {numeroFuncionario}\nSALARIO R$ = {salario:.2f}')
# Out:
# 25
# 100
# 5.50
# NUMERO = 25
# SALARIO R$ = 550.00

# %% [markdown]
# [1002 - Área do Círculo](https://www.beecrowd.com.br/judge/pt/problems/view/1002)

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# [1011 - Esfera](https://www.beecrowd.com.br/judge/pt/problems/view/1011)

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# [1013 - O Maior](https://www.beecrowd.com.br/judge/pt/problems/view/1013)
#
# ![formula](https://resources.urionlinejudge.com.br/gallery/images/problems/UOJ_1013.png)

# %%
# -*- coding: utf-8 -*-
maiorAB = (a+b+abs(a-b))/2
a = int(input())
b = int(input())
c = int(input())

if a > b > c:
  print(a, ' Eh o maior')
elif b > a > c:
  print(b, ' Eh o maior')
else:
  print(c, ' Eh o maior')
# Out:
# 4
# 14
# 15
# 15  Eh o maior

# %% [markdown]
# [1006 - Média 2](https://www.beecrowd.com.br/judge/pt/problems/view/1006)

# %%
# -*- coding: utf-8 -*-
'''
Leia 3 valores, no caso, variáveis A, B e C, que são as três notas de um aluno. A seguir, calcule a média do aluno, sabendo que a nota A tem peso 2, 
a nota B tem peso 3 e a nota C tem peso 5. Considere que cada nota pode ir de 0 até 10.0, sempre com uma casa decimal.

Entrada
O arquivo de entrada contém 3 valores com uma casa decimal, de dupla precisão (double).

Saída
Imprima a mensagem "MEDIA" e a média do aluno conforme exemplo abaixo, com 1 dígito após o ponto 
decimal e com um espaço em branco antes e depois da igualdade. Assim como todos os problemas, não 
esqueça de imprimir o fim de linha após o resultado, caso contrário, você receberá "Presentation Error".
'''
A = (float(input()))
B = (float(input()))
C = (float(input()))

media = (((A*2)+(B*3)+(C*5))/10)

print(f'MEDIA = ', media, ' ')
# Out:
# 10
# 5
# 2
# MEDIA = 4.5

# %% [markdown]
# [1094 - Experiências](https://www.beecrowd.com.br/judge/pt/problems/view/1094)

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# [1151 - Fibonacci Fácil](https://www.beecrowd.com.br/judge/pt/problems/view/1151)

# %%
# -*- coding: utf-8 -*-
a, b, c = int(input(a,b,c))

# %% [markdown]
# [1070 - Seis Números Ímpares](https://www.beecrowd.com.br/judge/pt/problems/view/1070)

# %%
# Out:
#   File "<ipython-input-36-d3b4fcbec601>", line 7
#     if(x % 2 == 1):
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# [1177 - Preenchimento de Vetor II](https://www.beecrowd.com.br/judge/pt/problems/view/1177)

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# [2569 - A Bruxa do 7 x 1](https://www.beecrowd.com.br/judge/pt/problems/view/2569)

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# [1142 - PUM](https://www.beecrowd.com.br/judge/pt/problems/view/1142)

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# [1078 - Tabuada](https://www.beecrowd.com.br/judge/pt/problems/view/1078)

# %%
# -*- coding: utf-8 -*-

# n = int(input())
# if(2 < n < 1000):  
#   print(f'1 x {n} = ',n*1)
#   print(f'2 x {n} = ',n*2)
#   print(f'3 x {n} = ',n*3)
#   print(f'4 x {n} = ',n*4)
#   print(f'5 x {n} = ',n*5)
#   print(f'6 x {n} = ',n*6)
#   print(f'7 x {n} = ',n*7)
#   print(f'8 x {n} = ',n*8)
#   print(f'9 x {n} = ',n*9)
#   print(f'10 x {n} = ',n*10)

while True:
    n = int(input())
    if n < 0:
        break
    for c in range(1, 11):
        print(f'{n}x{c} = {n*c}')
# Out:
# Digite um valor para ver a sua tabuada: 2
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# 2x1 = 2
# 2x2 = 4
# 2x3 = 6
# 2x4 = 8
# 2x5 = 10
# 2x6 = 12
# 2x7 = 14
# 2x8 = 16
# 2x9 = 18
# 2x10 = 20
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-eec09ae85ad6> in <module>
#      15
#      16 while True:
# ---> 17     valor = int(input('Digite um valor para ver a sua tabuada: '))
#      18     if valor < 0:
#      19         break
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ...

# %% [markdown]
# [2473 - Loteria](https://www.beecrowd.com.br/judge/pt/problems/view/2473)

# %%
# -*- coding: utf-8 -*-

# %% [markdown]
# [2650 - Construindo Muralhas](https://www.beecrowd.com.br/judge/pt/problems/view/2650)

# %%
# -*- coding: utf-8 -*-
