# %% [markdown]
# <img src="https://www.cesar.school/wp-content/uploads/2019/09/marca_cesar_school.png" alt="drawing" width="200"/>
#
# # 🐍 Python - **Aula 09**
#
# ---
#
# - Tuple
# - Set
# - Dict

# %% [markdown]
# # Estruturas de Dados
#
# Sempre que precisamos armazenar vários dados em uma única variável se faz necessário usar algum tipo de dado **Container**. Em Python, os principais são:
# - `list`;
# - `tuple`;
# - `set`;
# - `dict`;
#
# Cada containers, ou tipos de coleção, tem uma característica específica e um uso diferente. Nesta aula vamos conhecer um pouco mais sobre eles.

# %% [markdown]
# ## 🪨 `tuple`
#
# Ao usar listas, há bastante liberdade para alterar seus itens. Em determinadas situções, essas listas não deveriam ser alteradas, tais como:
# - Dias da semana;
# - Coordenadas de um prédio;
# - Letras de um alfabeto.
#
# > ### Características:
# - Imutáveis;
# - Ordenados/indexável;
# - Permite elementos duplicados.
#
#
# ```python
# t = ('domingo', 'segunda', 'terça', 'quarta', 'quinta', 'sexta', 'sábado')
# ```
#
# > 💡 Obs.: *O acesso aos elementos de uma tupla é feito da mesma forma que com listas*

# %%
# Criação de uma Tupla
dias_uteis = ('segunda', 'terça', 'quarta', 'quinta', 'sexta')
naipes = 'espadas', 'paus', 'copas', 'ouro'

print(dias_uteis)
print(type(naipes))

# Acesso aos elementos de uma Tupla
print(dias_uteis[:2])

# len()
print(len(dias_uteis))

# tupla.index(item)
print(dias_uteis.index('sexta'))
print('domingo' in dias_uteis)

# tupla.count(item)
print(naipes.count('ouro'))

# Imutabilidade
dias_uteis[0] = 'domingo'
# Out:
# ('segunda', 'terça', 'quarta', 'quinta', 'sexta')
# <class 'tuple'>
# ('segunda', 'terça')
# 5
# 4
# False
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a33daff2155e> in <module>
#      20
#      21 # Imutabilidade
# ---> 22 dias_uteis[0] = 'domingo'
#
# TypeError: 'tuple' object does not support item assignment

# %%
entrada = tuple(input('Insira os nomes das pessoas: ').split())

print(type(entrada))
print(entrada)

#tupla_entrada = tuple(entrada)

#print(type(tupla_entrada))
#print(tupla_entrada)
# Out:
# Insira os nomes das pessoas: fabricio alycia everton vieira lev
# <class 'tuple'>
# ('fabricio', 'alycia', 'everton', 'vieira', 'lev')

# %% [markdown]
# ## 💎 `set`
#
# Tanto em **listas**, quanto em **tuplas**, é possível ter elementos repetidos:
#
# ```python
# t = (0, 1, 1, 2, 3, 5)
# l = [0, 1, 1, 2, 3, 5]
# ```
#
# Quanto houver uma situação onde você não deva armazenar itens repetidos numa lista, é possível usar um `set`:
#
# ```python
# s1 = set()
# s.add(1)
# s.add(2)
# s.add(1)
#
# s2 = {'bacon', 'banana', 'spam', 'ovos', 'spam', 'salsicha', 'spam'}
# ```
#
# > ### Características:
# - Imutáveis (mas podem ser adicionados e removidos);
# - Não Ordenados/ não indexável;
# - Não Permite elementos duplicados.

# %%
# criar um set
monitores = set()
ingredientes = {'bacon', 'ovos', 'spam', 'spam', 'spam'}

print(type(monitores))
print(monitores)

#print(ingredientes[0]) # erro!

# adicionar elementos
monitores.add('Lev')
monitores.add('João')
monitores.add('Patrick')
monitores.add('Lev')
monitores.add('João')
monitores.add('Patrick')
monitores.add('Lev')
monitores.add('João')
monitores.add('Patrick')

print(monitores)

nums = [1, 2, 3, 1, 4, 5, 5, 5, 5, 7, 8, 9, 1]
print(len(set(nums)))
nums_n_repetidos = set(nums)

print(nums_n_repetidos)

# remover elementos
print(ingredientes)
ingredientes.remove('spam')
print(ingredientes)
# Out:
# <class 'set'>
# set()
# {'Lev', 'João', 'Patrick'}
# 8
# {1, 2, 3, 4, 5, 7, 8, 9}
# {'spam', 'ovos', 'bacon'}
# {'ovos', 'bacon'}

# %%
ingredientes = {'bacon', 'ovos', 'spam', 'spam', 'spam'}

for item in ingredientes:
  print(item)
# Out:
# spam
# ovos
# bacon

# %%
ingredientes = ['bacon', 'ovos', 'spam', 'spam', 'spam']

quant_maior = len(ingredientes)
quant_unicos = len(set(ingredientes))

print(quant_maior - quant_unicos)

for item in ingredientes:
  print(item)
# Out:
# 2
# bacon
# ovos
# spam
# spam
# spam

# %%
n = set([1, 1.0, 'omena', False, 0])

print(n)
# Out:
# {False, 1, 'omena'}

# %%
nomes = set()
for _ in range(5):
  nomes.add(input('Insira o nome, meu consagrado: '))

print(nomes)
# Out:
# Insira o nome, meu consagrado: alycia
# Insira o nome, meu consagrado: nanda
# Insira o nome, meu consagrado: alycia
# Insira o nome, meu consagrado: nanda
# Insira o nome, meu consagrado: omena
# {'omena', 'nanda', 'alycia'}

# %% [markdown]
# ## 🔑 Dicionários
#
# Para criar estruturas de dados que são mapeados por valores (e não pelo indice, como nas listas) é possível usar um dicionário.
#
# > **Chave** x **Valor**
#
# Obs.: *O mapeamento é feito pela chave (e não pela ordem)*
#
# Exemplos de uso prático:
# - Dicionários;
# - CEP;
#
# ```python
# dicionario = {'chave': 'valor1', 'chave2': 'valor2'}
# ```
#
# > ### Características:
# - Mutáveis;
# - Ordenados/indexável;
# - Permite valores duplicados (mas não a chave).

# %%
# Criando um dicionário
cep = {'5102154': ('Avenida cais da rua', 'Recife Antigo', 'PE'),
       '5355647': 'Rua da saudade que não vai',
       '1125478': 'Rua da avendia da estrada'
       }
tradutor = {'dog':'cão', 'lion':'leão', 'bird':'pássaro'}
agenda = {'mãe':(123456, 789456, 88774455), 'pai':(753159,)}

# Acessando elementos de um dicionário
print(tradutor['dog'])
print(tradutor['bird'])

print(len(agenda['mãe']))
print(agenda['mãe'][-1])

# Adição de itens por atribuição
pokemon = dict()

pokemon['Charmander'] = 'fogo'
pokemon['Psyduck'] = 'psiquico', 'agua'

print(pokemon)

pokemon['Psyduck'] = 'agua'

#nome = input('Insira o nome: ')
#tipo = input('Qual o tipo? ')

#pokemon[nome] = tipo

print(pokemon)

print(len(agenda['mãe']))
print(len(agenda['pai']))

# Adição de itens por update
pokemon.update({'Pikachu':'Elétrico'})
print(pokemon)

# Removendo itens
#pokemon.popitem()
print(pokemon)

#pokemon.pop('Psyduck')
#del pokemon['Psyduck']
print(pokemon)

# esvaziando um dicionário
#pokemon.clear()
print(pokemon)
# Out:
# cão
# pássaro
# 3
# 88774455
# {'Charmander': 'fogo', 'Psyduck': ('psiquico', 'agua')}
# {'Charmander': 'fogo', 'Psyduck': 'agua'}
# 3
# 1
# {'Charmander': 'fogo', 'Psyduck': 'agua', 'Pikachu': 'Elétrico'}
# {'Charmander': 'fogo', 'Psyduck': 'agua', 'Pikachu': 'Elétrico'}
# {'Charmander': 'fogo', 'Psyduck': 'agua', 'Pikachu': 'Elétrico'}
# {'Charmander': 'fogo', 'Psyduck': 'agua', 'Pikachu': 'Elétrico'}

# %%
pokemons = dict()

for _ in range(5):
  key = input('Insira o nome do Pokemon: ')
  value = input('Qual o tipo desse Pokemon? ')

  pokemons[key] = value

print(pokemons)
# Out:
# Insira o nome do Pokemon: charmander
# Qual o tipo desse Pokemon? fogo
# Insira o nome do Pokemon: aaaaa
# Qual o tipo desse Pokemon? bbbb
# Insira o nome do Pokemon: cccc
# Qual o tipo desse Pokemon? dddd
# Insira o nome do Pokemon: eeee
# Qual o tipo desse Pokemon? ffff
# Insira o nome do Pokemon: gggg
# Qual o tipo desse Pokemon? hhhhh
# {'charmander': 'fogo', 'aaaaa': 'bbbb', 'cccc': 'dddd', 'eeee': 'ffff', 'gggg': 'hhhhh'}

# %% [markdown]
# ### 🗝️ Alguns métodos úteis de dicionários
#
# - `dict.keys()` - Apresenta todas as chaves do dicionário
# - `dict.values()` - Apresenta todos os valores do dicionário
# - `dict.items()` - `dict_keys()` + `dict_values()`

# %%
# keys()
print(pokemon.keys())
#print(list(pokemon.keys())[:2])

# values()
print(pokemon.values())

# items()
print(pokemon.items())

# for
for elem in pokemon:
  print(elem)

print('*'*20)

for elem in pokemon.values():
  print(elem)

print('*'*20)

for elem in pokemon.items():
  print(elem)
  print(f'A chave é {elem[0]} e o valor é {elem[1]}')

print('*'*20)

for nome, tipo in pokemon.items():
  print(f'O pokemon {nome} é do tipo {tipo}')
# Out:
# dict_keys(['Charmander', 'Psyduck', 'Pikachu'])
# dict_values(['fogo', 'agua', 'Elétrico'])
# dict_items([('Charmander', 'fogo'), ('Psyduck', 'agua'), ('Pikachu', 'Elétrico')])
# Charmander
# Psyduck
# Pikachu
# ********************
# fogo
# agua
# Elétrico
# ********************
# ('Charmander', 'fogo')
# A chave é Charmander e o valor é fogo
# ('Psyduck', 'agua')
# A chave é Psyduck e o valor é agua
# ('Pikachu', 'Elétrico')
# A chave é Pikachu e o valor é Elétrico
# ********************
# O pokemon Charmander é do tipo fogo
# O pokemon Psyduck é do tipo agua
# O pokemon Pikachu é do tipo Elétrico

# %%
agenda = {'mãe':('123456', '789456', '88774455'),
          'pai':('753159',),
          'Shell':('123456', '654987'),
          'Padilha':('00000',)}

for contato, telefones in agenda.items():
  print(contato, telefones)
# Out:
# mãe ('123456', '789456', '88774455')
# pai ('753159',)
# Shell ('123456', '654987')
# Padilha ('00000',)

# %% [markdown]
# ## 📋 Resumão
#
# | Tipo  |Mutável|Ordenado|Indexável| Elementros Duplicados
# |-------|-------|--------|---------|----------------------|
# |`list` |   ✅  |   ✅  |   ✅   |          ✅          |
# |`tuple`|   ❌  |   ✅  |   ✅   |          ✅          |
# | `set` |   ✅  |   ❌  |   ❌   |          ❌          |
# |`dict` |   ✅  |   ✅  |   ✅*  |          ✅          |

# %% [markdown]
# # 🐝 Exercícios Beecrowd

# %% [markdown]
# [2653 - Dijkstra](https://www.beecrowd.com.br/judge/pt/problems/view/2653)

# %%
# -*- coding: utf-8 -*-

joias = set()

while True:
  try:
    joias.add(input())
  except:
    break

print(len(joias))
# Out:
# (((
# ((
# (
# ()
# ()))
# ()()()
# 6

# %% [markdown]
# [1050 - DDD](https://www.beecrowd.com.br/judge/pt/problems/view/1050)

# %%
# -*- coding: utf-8 -*-

ddds = {'61': 'Brasilia',
        '71':'Salvador',
        '11':'Sao Paulo',
        '21':'Rio de Janeiro',
        '32':'Juiz de Fora',
        '19':'Campinas',
        '27':'Vitoria',
        '31':'Belo Horizonte'}

ddd = input()

print(ddds.get(ddd, 'DDD nao cadastrado'))
# Out:
# DDD nao cadastrado

# %% [markdown]
# [1168 - LED](https://www.beecrowd.com.br/judge/pt/problems/view/1168)

# %%
# -*- coding: utf-8 -*-

d = {'1': 2,
     '2': 5,
     '3': 5,
     '4': 4,
     '5': 5,
     '6': 6,
     '7': 3,
     '8': 7,
     '9': 6,
     '0': 6}

n = int(input())
for i in range(n):
  v = input()
  leds = 0
  for c in v:
    leds += d[c]

  print(f'{leds} leds')

# %% [markdown]
# # 🧱 Exercícios Fundamentais

# %% [markdown]
# 1. Dada a lista a seguir, crie uma nova lista onde cada um desses elementos aparece apenas uma única vez.
# ```python
# l = [1, 3, 2, 3, 4, 5, 1, 5, 7, 6, 8, 3, 4]
# ```

# %%
l = [1, 3, 2, 3, 4, 5, 1, 5, 7, 6, 8, 3, 4]
s = set()

for item in l:
  s.add(item)

print(s)

# %%
l = [1, 3, 2, 3, 4, 5, 1, 5, 7, 6, 8, 3, 4]
s = set(l)

print(s)

# %% [markdown]
# 2. Crie um programa com duas funções. A primeira deve pedir um CEP e o endereço do usuário e armazena-lo em um dicionário. A segunda deve pesquisar um endereço, buscando pelo CEP informado.
#
# 🏆 Desafio: Armazene o dicionário em um arquivo.

# %%
ceps = {}

def inclui_endereco():
  cep = input('Insira um CEP: ')
  endereco = input(f'Insira um endereço do CEP {cep}: ')

  ceps.update({cep:endereco})


def busca_endereco():
  cep = input('Insira um CEP que você deseja buscar: ')

  print(ceps.get(cep, 'CEP não encontrado'))

while True:
  entrada = input('O que você deseja fazer:\n\t1 - Inserir um CEP\n\t2 - Buscar um CEP\n\t3 - Sair\n')

  if entrada == '1':
    inclui_endereco()
  elif entrada == '2':
    busca_endereco()
  elif entrada == '3':
    print('Volte sempre!')
    break
  else:
    print('Comando inválido, tente novamente...')

  print(ceps)
